# %% [markdown]
# - 2020-Jan.csv 4,264,752 rows; 2020-Feb.csv: 4,156,682 rows; the two datasets were combined.
# - Event type distribution: view (77.21%), cart (17.45%), purchase (5.33%).
# - Funnel stages: view, cart, purchase.
# - View to cart conversion rate: 22.60%.
# - Cart to purchase conversion rate: 30.53%.
# - Overall view to purchase conversion rate: 6.90%.
# - The conversion rate decreased by 0.3 percentage points in February compared with January.
# - Category with the highest conversion rate: runail (17.9%).
# - The top 5 brands account for 44.69% of total purchases by purchase count.
# - Average purchase value: 5.00$; maximum: 327.78$ (potential outlier).
